# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hosammhmdali/supermarket-sales")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.8).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/hosammhmdali/supermarket-sales?dataset_version_number=1...
# 100%|██████████| 35.9k/35.9k [00:00<00:00, 16.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/hosammhmdali/supermarket-sales/versions/1

# %%
ls /root/.cache/kagglehub/datasets/hosammhmdali/supermarket-sales/versions/1
# Out:
# 'supermarket_sales -.csv'

# %%
import pandas as pd
path = '/root/.cache/kagglehub/datasets/hosammhmdali/supermarket-sales/versions/1/supermarket_sales -.csv'
df = pd.read_csv(path)

df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
df = df.drop(['Invoice ID'], axis = 1)
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 0         74.69         7  26.1415   548.9715   1/5/2019  13:08      Ewallet
# 1         15.28         5   3.8200    80.2200   3/8/2019  10:29         Cash
# 2         46.33         7  16.2155   340.5255   3/3/2019  13:23  Credit card
# 3         58.22         8  23.2880   489.0480  1/27/2019  20:33      Ewallet
# 4         86.31         7  30.2085   634.3785   2/8/2019  10:37      Ewallet
# ..          ...       ...      ...        ...        ...    ...          ...
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46      Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16      Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22         Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33         Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28         Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 0    522.83                 4.761905       26.1415     9.1
# 1     76.40                 4.761905        3.8200     9.6
# 2    324.31                 4.761905       16.2155     7.4
# 3    465.76                 4.761905       23.2880     8.4
# 4    604.17                 4.761905       30.2085     5.3
# ..      ...                      ...           ...     ...
# 995   40.35                 4.761905        2.0175     6.2
# 996  973.80                 4.761905       48.6900     4.4
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6
#
# [1000 rows x 16 columns]

# %%
df['Branch'].nunique()
# Out:
# 3

# %%
df['Branch'] = df['Branch'].map({'A': 1, 'B': 2, 'C': 3})
df
# Out:
#      Branch       City Customer type  Gender            Product line  \
# 0         1     Yangon        Member  Female       Health and beauty
# 1         3  Naypyitaw        Normal  Female  Electronic accessories
# 2         1     Yangon        Normal    Male      Home and lifestyle
# 3         1     Yangon        Member    Male       Health and beauty
# 4         1     Yangon        Normal    Male       Sports and travel
# ..      ...        ...           ...     ...                     ...
# 995       3  Naypyitaw        Normal    Male       Health and beauty
# 996       2   Mandalay        Normal  Female      Home and lifestyle
# 997       1     Yangon        Member    Male      Food and beverages
# 998       1     Yangon        Normal    Male      Home and lifestyle
# 999       1     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 0         74.69         7  26.1415   548.9715   1/5/2019  13:08      Ewallet
# 1         15.28         5   3.8200    80.2200   3/8/2019  10:29         Cash
# 2         46.33         7  16.2155   340.5255   3/3/2019  13:23  Credit card
# 3         58.22         8  23.2880   489.0480  1/27/2019  20:33      Ewallet
# 4         86.31         7  30.2085   634.3785   2/8/2019  10:37      Ewallet
# ..          ...       ...      ...        ...        ...    ...          ...
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46      Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16      Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22         Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33         Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28         Cash
#
#        cogs  gross margin percentage  gross income  Rating
# 0    522.83                 4.761905       26.1415     9.1
# 1     76.40                 4.761905        3.8200     9.6
# 2    324.31                 4.761905       16.2155     7.4
# 3    465.76                 4.761905       23.2880     8.4
# 4    604.17                 4.761905       30.2085     5.3
# ..      ...                      ...           ...     ...
# 995   40.35                 4.761905        2.0175     6.2
# 996  973.80                 4.761905       48.6900     4.4
# 997   31.84                 4.761905        1.5920     7.7
# 998   65.82                 4.761905        3.2910     4.1
# 999  618.38                 4.761905       30.9190     6.6
#
# [1000 rows x 16 columns]

# %%
df['City'].nunique()
# Out:
# 3

# %%
df['City'] = df['City'].replace({'Yangon': 1, 'Naypyitaw': 2, 'Mandalay': 3})
df
# Out:
# <ipython-input-29-b1bd2ae92ab5>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['City'] = df['City'].replace({'Yangon': 1, 'Naypyitaw': 2, 'Mandalay': 3})
#      Branch  City Customer type  Gender            Product line  Unit price  \
# 0         1     1        Member  Female       Health and beauty       74.69
# 1         3     2        Normal  Female  Electronic accessories       15.28
# 2         1     1        Normal    Male      Home and lifestyle       46.33
# 3         1     1        Member    Male       Health and beauty       58.22
# 4         1     1        Normal    Male       Sports and travel       86.31
# ..      ...   ...           ...     ...                     ...         ...
# 995       3     2        Normal    Male       Health and beauty       40.35
# 996       2     3        Normal  Female      Home and lifestyle       97.38
# 997       1     1        Member    Male      Food and beverages       31.84
# 998       1     1        Normal    Male      Home and lifestyle       65.82
# 999       1     1        Member  Female     Fashion accessories       88.34
#
#      Quantity   Tax 5%      Total       Date   Time      Payment    cogs  \
# 0           7  26.1415   548.9715   1/5/2019  13:08      Ewallet  522.83
# 1           5   3.8200    80.2200   3/8/2019  10:29         Cash   76.40
# 2           7  16.2155   340.5255   3/3/2019  13:23  Credit card  324.31
# 3           8  23.2880   489.0480  1/27/2019  20:33      Ewallet  465.76
# 4           7  30.2085   634.3785   2/8/2019  10:37      Ewallet  604.17
# ..        ...      ...        ...        ...    ...          ...     ...
# 995         1   2.0175    42.3675  1/29/2019  13:46      Ewallet   40.35
# 996        10  48.6900  1022.4900   3/2/2019  17:16      Ewallet  973.80
# 997         1   1.5920    33.4320   2/9/2019  13:22         Cash   31.84
# 998         1   3.2910    69.1110  2/22/2019  15:33         Cash   65.82
# 999         7  30.9190   649.2990  2/18/2019  13:28         Cash  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 16 columns]

# %%
df['Customer type'].nunique()
# Out:
# 2

# %%
df['Customer type'] = df['Customer type'].replace({'Member': 1, 'Normal': 2})
df
# Out:
# <ipython-input-31-fb267eab56c7>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Customer type'] = df['Customer type'].replace({'Member': 1, 'Normal': 2})
#      Branch  City  Customer type  Gender            Product line  Unit price  \
# 0         1     1              1  Female       Health and beauty       74.69
# 1         3     2              2  Female  Electronic accessories       15.28
# 2         1     1              2    Male      Home and lifestyle       46.33
# 3         1     1              1    Male       Health and beauty       58.22
# 4         1     1              2    Male       Sports and travel       86.31
# ..      ...   ...            ...     ...                     ...         ...
# 995       3     2              2    Male       Health and beauty       40.35
# 996       2     3              2  Female      Home and lifestyle       97.38
# 997       1     1              1    Male      Food and beverages       31.84
# 998       1     1              2    Male      Home and lifestyle       65.82
# 999       1     1              1  Female     Fashion accessories       88.34
#
#      Quantity   Tax 5%      Total       Date   Time      Payment    cogs  \
# 0           7  26.1415   548.9715   1/5/2019  13:08      Ewallet  522.83
# 1           5   3.8200    80.2200   3/8/2019  10:29         Cash   76.40
# 2           7  16.2155   340.5255   3/3/2019  13:23  Credit card  324.31
# 3           8  23.2880   489.0480  1/27/2019  20:33      Ewallet  465.76
# 4           7  30.2085   634.3785   2/8/2019  10:37      Ewallet  604.17
# ..        ...      ...        ...        ...    ...          ...     ...
# 995         1   2.0175    42.3675  1/29/2019  13:46      Ewallet   40.35
# 996        10  48.6900  1022.4900   3/2/2019  17:16      Ewallet  973.80
# 997         1   1.5920    33.4320   2/9/2019  13:22         Cash   31.84
# 998         1   3.2910    69.1110  2/22/2019  15:33         Cash   65.82
# 999         7  30.9190   649.2990  2/18/2019  13:28         Cash  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 16 columns]

# %%
df['Gender'] = df['Gender'].replace({'Female': 0, 'Male': 1})
df
# Out:
# <ipython-input-32-b58f7777d4e5>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'] = df['Gender'].replace({'Female': 0, 'Male': 1})
#      Branch  City  Customer type  Gender            Product line  Unit price  \
# 0         1     1              1       0       Health and beauty       74.69
# 1         3     2              2       0  Electronic accessories       15.28
# 2         1     1              2       1      Home and lifestyle       46.33
# 3         1     1              1       1       Health and beauty       58.22
# 4         1     1              2       1       Sports and travel       86.31
# ..      ...   ...            ...     ...                     ...         ...
# 995       3     2              2       1       Health and beauty       40.35
# 996       2     3              2       0      Home and lifestyle       97.38
# 997       1     1              1       1      Food and beverages       31.84
# 998       1     1              2       1      Home and lifestyle       65.82
# 999       1     1              1       0     Fashion accessories       88.34
#
#      Quantity   Tax 5%      Total       Date   Time      Payment    cogs  \
# 0           7  26.1415   548.9715   1/5/2019  13:08      Ewallet  522.83
# 1           5   3.8200    80.2200   3/8/2019  10:29         Cash   76.40
# 2           7  16.2155   340.5255   3/3/2019  13:23  Credit card  324.31
# 3           8  23.2880   489.0480  1/27/2019  20:33      Ewallet  465.76
# 4           7  30.2085   634.3785   2/8/2019  10:37      Ewallet  604.17
# ..        ...      ...        ...        ...    ...          ...     ...
# 995         1   2.0175    42.3675  1/29/2019  13:46      Ewallet   40.35
# 996        10  48.6900  1022.4900   3/2/2019  17:16      Ewallet  973.80
# 997         1   1.5920    33.4320   2/9/2019  13:22         Cash   31.84
# 998         1   3.2910    69.1110  2/22/2019  15:33         Cash   65.82
# 999         7  30.9190   649.2990  2/18/2019  13:28         Cash  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 16 columns]

# %%
df['Product line'].nunique()
# Out:
# 6

# %%
df['Product line'] = df['Product line'].replace({'Health and beauty': 1, 'Home and lifestyle': 2, 'Electronic accessories': 3, 'Sports and travel': 4, 'Food and beverages': 5, 'Fashion accessories': 6})
df
# Out:
# <ipython-input-34-99b4ee99b6af>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Product line'] = df['Product line'].replace({'Health and beauty': 1, 'Home and lifestyle': 2, 'Electronic accessories': 3, 'Sports and travel': 4, 'Food and beverages': 5, 'Fashion accessories': 6})
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0         1     1              1       0             1       74.69         7
# 1         3     2              2       0             3       15.28         5
# 2         1     1              2       1             2       46.33         7
# 3         1     1              1       1             1       58.22         8
# 4         1     1              2       1             4       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       3     2              2       1             1       40.35         1
# 996       2     3              2       0             2       97.38        10
# 997       1     1              1       1             5       31.84         1
# 998       1     1              2       1             2       65.82         1
# 999       1     1              1       0             6       88.34         7
#
#       Tax 5%      Total       Date   Time      Payment    cogs  \
# 0    26.1415   548.9715   1/5/2019  13:08      Ewallet  522.83
# 1     3.8200    80.2200   3/8/2019  10:29         Cash   76.40
# 2    16.2155   340.5255   3/3/2019  13:23  Credit card  324.31
# 3    23.2880   489.0480  1/27/2019  20:33      Ewallet  465.76
# 4    30.2085   634.3785   2/8/2019  10:37      Ewallet  604.17
# ..       ...        ...        ...    ...          ...     ...
# 995   2.0175    42.3675  1/29/2019  13:46      Ewallet   40.35
# 996  48.6900  1022.4900   3/2/2019  17:16      Ewallet  973.80
# 997   1.5920    33.4320   2/9/2019  13:22         Cash   31.84
# 998   3.2910    69.1110  2/22/2019  15:33         Cash   65.82
# 999  30.9190   649.2990  2/18/2019  13:28         Cash  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 16 columns]

# %%
df['Payment'] = df['Payment'].replace({'Ewallet': 1, 'Cash': 2, 'Credit card': 3})
df
# Out:
# <ipython-input-35-119d07bba15d>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Payment'] = df['Payment'].replace({'Ewallet': 1, 'Cash': 2, 'Credit card': 3})
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0         1     1              1       0             1       74.69         7
# 1         3     2              2       0             3       15.28         5
# 2         1     1              2       1             2       46.33         7
# 3         1     1              1       1             1       58.22         8
# 4         1     1              2       1             4       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       3     2              2       1             1       40.35         1
# 996       2     3              2       0             2       97.38        10
# 997       1     1              1       1             5       31.84         1
# 998       1     1              2       1             2       65.82         1
# 999       1     1              1       0             6       88.34         7
#
#       Tax 5%      Total       Date   Time  Payment    cogs  \
# 0    26.1415   548.9715   1/5/2019  13:08        1  522.83
# 1     3.8200    80.2200   3/8/2019  10:29        2   76.40
# 2    16.2155   340.5255   3/3/2019  13:23        3  324.31
# 3    23.2880   489.0480  1/27/2019  20:33        1  465.76
# 4    30.2085   634.3785   2/8/2019  10:37        1  604.17
# ..       ...        ...        ...    ...      ...     ...
# 995   2.0175    42.3675  1/29/2019  13:46        1   40.35
# 996  48.6900  1022.4900   3/2/2019  17:16        1  973.80
# 997   1.5920    33.4320   2/9/2019  13:22        2   31.84
# 998   3.2910    69.1110  2/22/2019  15:33        2   65.82
# 999  30.9190   649.2990  2/18/2019  13:28        2  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 16 columns]

# %%
import pandas as pd
path = '/root/.cache/kagglehub/datasets/hosammhmdali/supermarket-sales/versions/1/supermarket_sales -.csv'
df = pd.read_csv(path)

df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
# Define Event A: A transaction is made by a Member customer.
df['Event_A'] = df['Customer type'] == 'Member'

# Define Event B: A transaction was made using Credit Card payment.
df['Event_B'] = df['Payment'] == 'Credit card'

# Display the first few rows to show the new columns
print(df[['Customer type', 'Payment', 'Event_A', 'Event_B']].head())
# Out:
#   Customer type      Payment  Event_A  Event_B
# 0        Member      Ewallet     True    False
# 1        Normal         Cash    False    False
# 2        Normal  Credit card    False     True
# 3        Member      Ewallet     True    False
# 4        Normal      Ewallet    False    False

# %%
# Calculate P(A)
p_a = df['Event_A'].sum() / len(df)

# Calculate P(B)
p_b = df['Event_B'].sum() / len(df)

# Calculate P(A ∩ B)
p_a_intersect_b = len(df[(df['Event_A'] == True) & (df['Event_B'] == True)]) / len(df)

# Calculate P(A ∪ B)
p_a_union_b = p_a + p_b - p_a_intersect_b

# Calculate P(A | B)
p_a_given_b = p_a_intersect_b / p_b

# Print the results
print(f"P(A): {p_a}")
print(f"P(B): {p_b}")
print(f"P(A ∩ B): {p_a_intersect_b}")
print(f"P(A ∪ B): {p_a_union_b}")
print(f"P(A | B): {p_a_given_b}")
# Out:
# P(A): 0.501
# P(B): 0.311
# P(A ∩ B): 0.172
# P(A ∪ B): 0.6400000000000001
# P(A | B): 0.5530546623794211

# %%
# Calculate the probability of a transaction belonging to Health & Beauty
health_beauty_count = len(df[df['Product line'] == 'Health and beauty'])
total_transactions = len(df)
probability_health_beauty = health_beauty_count / total_transactions

print(f"The probability that a randomly chosen transaction belongs to the Health & Beauty product line is: {probability_health_beauty}")
# Out:
# The probability that a randomly chosen transaction belongs to the Health & Beauty product line is: 0.152

# %%
df['Event_C'] = df['Quantity'] > 5

# Define Event D: A transaction was made using Ewallet payment.
df['Event_D'] = df['Payment'] == 'Ewallet'

# Calculate P(C ∩ D)
p_c_intersect_d = len(df[(df['Event_C'] == True) & (df['Event_D'] == True)]) / len(df)

# Calculate P(D)
p_d = df['Event_D'].sum() / len(df)

# Calculate P(C | D)
p_c_given_d = p_c_intersect_d / p_d

# Print the result
print(f"P(C | D): {p_c_given_d}")
# Out:
# P(C | D): 0.4869565217391305

# %%
# Calculate the probability of a transaction from Yangon using Cash
yangon_cash_count = len(df[(df['City'] == 'Yangon') & (df['Payment'] == 'Cash')])
yangon_transactions = len(df[df['City'] == 'Yangon'])

probability_yangon_cash = yangon_cash_count / yangon_transactions

print(f"The probability that a randomly selected transaction from Yangon used Cash as the payment method is: {probability_yangon_cash}")
# Out:
# The probability that a randomly selected transaction from Yangon used Cash as the payment method is: 0.3235294117647059

# %%
# Define Event E: Customer is a Member
df['Event_E'] = df['Customer type'] == 'Member'

# Define Event F: Rating > 8
df['Event_F'] = df['Rating'] > 8

# Calculate P(E ∩ F)
p_e_intersect_f = len(df[(df['Event_E'] == True) & (df['Event_F'] == True)]) / len(df)

print(f"The probability of selecting a customer who is a Member and has given a rating above 8 is: {p_e_intersect_f}")
# Out:
# The probability of selecting a customer who is a Member and has given a rating above 8 is: 0.157

# %%
import math

def factorial(n):
  """Computes the factorial of a non-negative integer."""
  if n < 0:
    raise ValueError("Factorial is not defined for negative numbers.")
  elif n == 0:
    return 1
  else:
    return math.factorial(n)

def permutations(n, r):
  """Computes the number of permutations of n items taken r at a time."""
  if n < 0 or r < 0 or r > n:
    raise ValueError("Invalid input for permutations.")
  return factorial(n) // factorial(n - r)

def combinations(n, r):
  """Computes the number of combinations of n items taken r at a time."""
  if n < 0 or r < 0 or r > n:
    raise ValueError("Invalid input for combinations.")
  return factorial(n) // (factorial(r) * factorial(n - r))

# %%
# prompt: Use your functions to solve dataset-based scenarios.
n_transactions = 20
r_transactions = 5
permutations_result = permutations(n_transactions, r_transactions)
print(f"The number of permutations of 5 transactions from 20 is: {permutations_result}")

# Combination: How many ways can 3 different product lines be selected from the 6 available product categories?
n_product_lines = 6
r_product_lines = 3
combinations_result = combinations(n_product_lines, r_product_lines)
print(f"The number of combinations of 3 product lines from 6 is: {combinations_result}")

# Assuming 'Branch' is a column in your DataFrame
unique_branches = df['Branch'].unique()
num_branches = len(unique_branches)
factorial_result = factorial(num_branches)
print(f"The factorial of the number of branches is: {factorial_result}")
# Out:
# The number of permutations of 5 transactions from 20 is: 1860480
# The number of combinations of 3 product lines from 6 is: 20
# The factorial of the number of branches is: 6

# %%
def combinations(n, r):
  """Computes the number of combinations of n items taken r at a time."""
  if n < 0 or r < 0 or r > n:
    raise ValueError("Invalid input for combinations.")
  return math.factorial(n) // (math.factorial(r) * math.factorial(n - r))

available_payment_methods = 3
payment_methods_to_display = 4

# Since we need to display 4 payment methods but only have 3 available,
# we cannot form combinations directly.  We are likely repeating some payment methods.

# We need to consider this as permutations with repetitions
# This is the number of ways to choose 4 payment methods from 3 types, with repetition
ways_to_display = combinations(available_payment_methods + payment_methods_to_display - 1, payment_methods_to_display)

print(f"The number of ways to display 4 payment methods from 3 types (with repetition) is: {ways_to_display}")
# Out:
# The number of ways to display 4 payment methods from 3 types (with repetition) is: 15

# %%
def combinations(n, r):
  """Computes the number of combinations of n items taken r at a time."""
  if n < 0 or r < 0 or r > n:
    raise ValueError("Invalid input for combinations.")
  return math.factorial(n) // (math.factorial(r) * math.factorial(n - r))

total_employees = 15
employees_to_select = 5

ways_to_select = combinations(total_employees, employees_to_select)

print(f"The number of ways to select 5 employees from 15 is: {ways_to_select}")
# Out:
# The number of ways to select 5 employees from 15 is: 3003

# %%
import math

def combinations(n, r):
  """Computes the number of combinations of n items taken r at a time."""
  if n < 0 or r < 0 or r > n:
    raise ValueError("Invalid input for combinations.")
  return math.factorial(n) // (math.factorial(r) * math.factorial(n - r))

# Number of letters in the English alphabet
n = 26

# Number of letters to choose for the invoice code
r = 6

# Calculate the number of ways to create unique invoice codes
ways = combinations(n, r)

print(f"The number of ways to create unique invoice codes is: {ways}")
# Out:
# The number of ways to create unique invoice codes is: 230230
